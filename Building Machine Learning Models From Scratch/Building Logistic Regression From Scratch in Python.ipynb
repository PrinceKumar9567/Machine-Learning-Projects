# %% [markdown]
# Workflow Of the Logistic Regression Model:
#
# Step 1: Set the Learning rate and Number Of Iteration, Initiate the random weight and bias value
#
# Step 2: Build Sigmoid Function
#
# Step 3: Update the parameter using Gradient Descent
#
# Step 4: Build the "Predict" function to determine the class of the data point

# %%
#Importing the Numpy Library
import numpy as np

# %% [markdown]
# Logistic Regression Model

# %%
class Logistic_Regression():
    #Initializing the Hyperparameters(Learning rate and number of iterations)
    def __init__(self,learning_rate,no_of_iterations):
        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations
#Fit function to train the model with the dataset
    def fit(self,X,y):
        #number of training examples and number of features
        self.m,self.n = X.shape
        #initializing the weight and bias
        self.w = np.zeros(self.n)
        self.b = 0
        self.X = X
        self.y = y
        #implementing Gradient Descent 
        for i in range(self.no_of_iterations):
            self.update_weights()
        
    def update_weights(self):
        y_ = 1/(1+np.exp(-(self. X.dot(self.w)+self.b))) 
        #Calculating Gradients
        dw = ((self.X.T).dot(y_-self.y))/self.m
        db = (np.sum(y_-self.y))/self.m
        #updating the weights 
        self.w = self.w - self.learning_rate*dw
        self.b = self.b-self.learning_rate*db
        
    def predict(self,X):
        y_pred = 1/(1+np.exp(-(self. X.dot(self.w)+self.b))) 
        y_pred = np.where(y_pred>0.5,1,0)
        return y_pred

# %% [markdown]
# Importing the Dependencies

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis
#
# PIMA Diabetes Dataset

# %%
#Loading the Dataset to a pandas Dataframe
data = pd.read_csv(r"C:\Users\princ\OneDrive\Documents\Chapter 1\Python\Machine Learning\ML Data\diabetes.csv")

# %%
#Printing the first five rows of the dataset
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Number of rows and columns in  the dataset
data.shape
# Out:
# (768, 9)

# %%
data['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#Seprating the data and labels
features = data.drop(columns = 'Outcome',axis = 1)
Target = data['Outcome']

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(features)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(features)

# %%
X = standardized_data
y = diabetes_dataset['Outcome']

# %% [markdown]
# Splitting the data for training and testing data

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.2,random_state = 5)

# %% [markdown]
# Training the Model

# %%
Classifier = Logistic_Regression(learning_rate = 0.01,no_of_iterations = 1000)

# %%
#Training the classifier
Classifier.fit(X_train,y_train)

# %% [markdown]
# Model Evaluation

# %%
X_train_pred = Classifier.predict(X_train)
X_train_accuracy = accuracy_score(y_train,X_train_pred)

# %%
print('Accuracy of the Model is: ',X_train_accuracy)
# Out:
# Accuracy of the Model is:  0.760586319218241

# %% [markdown]
# Making a Predictive System

# %%
input_data = (5,166,72,19,175,25.8,0.587,51)
#Changing the input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)
#Reshaping the array as we are predicting for one instance only
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
#Standardizing the input data
std_data = scaler.transform(input_data_reshaped)
prediction = Classifier.predict(std_data)
print(prediction[0])

if (prediction[0] == 0):
    print('The person is not diabetic')
else:
    print('The person is Diabetic')
# Out:
# 0
# The person is not diabetic
# C:\Users\princ\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
